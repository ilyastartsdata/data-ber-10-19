# %%
# Importing the packages

import pandas as pd
import numpy as np

# %%
# Importing the csv file and debugging an encoding error

df = pd.read_csv("GSAF5.csv", encoding = "latin1")

# %%
# Displaying the first rows

df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# 0        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1        NaN  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3        NaN           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4  2 m shark           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
# 1  2016.09.18.b           5992         NaN         NaN
# 2  2016.09.18.a           5991         NaN         NaN
# 3    2016.09.17           5990         NaN         NaN
# 4    2016.09.15           5989         NaN         NaN
#
# [5 rows x 24 columns]

# %%
# Getting the clean date ouf of the case number column

df["clean_date"] = df["Case Number"].str.slice(0,10)

# %%
# Setting an index in order to access the interested in data directly

df.rename(columns = {"Case Number" : "case_number"}, inplace = True)
df = df.set_index("case_number")

# %% [markdown]
# ### Missing values & preparing the dataframe for analysis

# %%
# Counting the null values in columns

null_columns = df.isnull().sum()
null_columns[null_columns > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
# Are these nulls a majority for these columns?

null_columns[null_columns > 0] / len(df)
# Out:
# Country                   0.007176
# Area                      0.067089
# Location                  0.082777
# Activity                  0.087951
# Name                      0.033378
# Sex                       0.094626
# Age                       0.447430
# Injury                    0.004506
# Fatal (Y/N)               0.003171
# Time                      0.536215
# Species                   0.489653
# Investigator or Source    0.002503
# href formula              0.000167
# href                      0.000501
# Unnamed: 22               0.999833
# Unnamed: 23               0.999666
# dtype: float64

# %%
# It makes sence to drop the columns, which have more than 10% of null values
# as well as column, which doesn't provide any interesting information for us, such as pdf, href formula, href,
# case number 1, case number 2, original order

perc = null_columns[null_columns > 0] / len(df)
to_drop = perc[perc > 0.1].index
to_drop
# Out:
# Index(['Age', 'Time', 'Species ', 'Unnamed: 22', 'Unnamed: 23'], dtype='object')

# %%
# Dropping the columns, with specifired criteria (axis = 1)

df_adj = df.drop(to_drop, axis = 1)
df_adj = df_adj.drop(["href formula","href","pdf","Case Number.1","Case Number.2","original order","Date"], axis = 1)

# %%
# Look at new dataframe

df_adj.head()
# Out:
#               Year        Type    Country      Area  \
# case_number
# 2016.09.18.c  2016  Unprovoked        USA   Florida
# 2016.09.18.b  2016  Unprovoked        USA   Florida
# 2016.09.18.a  2016  Unprovoked        USA   Florida
# 2016.09.17    2016  Unprovoked  AUSTRALIA  Victoria
# 2016.09.15    2016  Unprovoked  AUSTRALIA  Victoria
#
#                                       Location Activity             Name Sex   \
# case_number
# 2016.09.18.c  New Smyrna Beach, Volusia County  Surfing             male    M
# 2016.09.18.b  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M
# 2016.09.18.a  New Smyrna Beach, Volusia County  Surfing             male    M
# 2016.09.17                    Thirteenth Beach  Surfing  Rory Angiolella    M
# 2016.09.15                         Bells Beach  Surfing             male    M
#
#                                              Injury Fatal (Y/N)  \
# case_number
# 2016.09.18.c                  Minor injury to thigh           N
# 2016.09.18.b                   Lacerations to hands           N
# 2016.09.18.a               Lacerations to lower leg           N
# 2016.09.17             Struck by fin on chest & leg           N
# 2016.09.15    No injury: Knocked off board by shark           N
#
#                    Investigator or Source  clean_date
# case_number
# 2016.09.18.c  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.b  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.a  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.17             The Age, 9/18/2016  2016.09.17
# 2016.09.15             The Age, 9/16/2016  2016.09.15

# %%
# Updating the column names

df_adj.columns = (df_adj.columns.str.replace(' ','_').str.lower())

# %%
# Checking if everything went well

df_adj.head()
# Out:
#               year        type    country      area  \
# case_number
# 2016.09.18.c  2016  Unprovoked        USA   Florida
# 2016.09.18.b  2016  Unprovoked        USA   Florida
# 2016.09.18.a  2016  Unprovoked        USA   Florida
# 2016.09.17    2016  Unprovoked  AUSTRALIA  Victoria
# 2016.09.15    2016  Unprovoked  AUSTRALIA  Victoria
#
#                                       location activity             name sex_  \
# case_number
# 2016.09.18.c  New Smyrna Beach, Volusia County  Surfing             male    M
# 2016.09.18.b  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M
# 2016.09.18.a  New Smyrna Beach, Volusia County  Surfing             male    M
# 2016.09.17                    Thirteenth Beach  Surfing  Rory Angiolella    M
# 2016.09.15                         Bells Beach  Surfing             male    M
#
#                                              injury fatal_(y/n)  \
# case_number
# 2016.09.18.c                  Minor injury to thigh           N
# 2016.09.18.b                   Lacerations to hands           N
# 2016.09.18.a               Lacerations to lower leg           N
# 2016.09.17             Struck by fin on chest & leg           N
# 2016.09.15    No injury: Knocked off board by shark           N
#
#                    investigator_or_source  clean_date
# case_number
# 2016.09.18.c  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.b  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.a  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.17             The Age, 9/18/2016  2016.09.17
# 2016.09.15             The Age, 9/16/2016  2016.09.15

# %%
# It did, but sex has now sex_, so we have to change it

df_adj.rename(columns = {"sex_" : "sex"}, inplace = True)

# %%
# Replacing the null values in country column

df_adj["country"] = df_adj["country"].fillna("UNKNOWN")

# %%
# Adjusting the values in country column

df_adj["country"] = df_adj["country"].str.title()
df_adj["country"] = df_adj["country"].replace("Usa","USA")
df_adj.head()
# Out:
#               year        type    country      area  \
# case_number
# 2016.09.18.c  2016  Unprovoked        USA   Florida
# 2016.09.18.b  2016  Unprovoked        USA   Florida
# 2016.09.18.a  2016  Unprovoked        USA   Florida
# 2016.09.17    2016  Unprovoked  Australia  Victoria
# 2016.09.15    2016  Unprovoked  Australia  Victoria
#
#                                       location activity             name sex  \
# case_number
# 2016.09.18.c  New Smyrna Beach, Volusia County  Surfing             male   M
# 2016.09.18.b  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   M
# 2016.09.18.a  New Smyrna Beach, Volusia County  Surfing             male   M
# 2016.09.17                    Thirteenth Beach  Surfing  Rory Angiolella   M
# 2016.09.15                         Bells Beach  Surfing             male   M
#
#                                              injury fatal_(y/n)  \
# case_number
# 2016.09.18.c                  Minor injury to thigh           N
# 2016.09.18.b                   Lacerations to hands           N
# 2016.09.18.a               Lacerations to lower leg           N
# 2016.09.17             Struck by fin on chest & leg           N
# 2016.09.15    No injury: Knocked off board by shark           N
#
#                    investigator_or_source  clean_date
# case_number
# 2016.09.18.c  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.b  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.a  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.17             The Age, 9/18/2016  2016.09.17
# 2016.09.15             The Age, 9/16/2016  2016.09.15

# %%
# Adjusting the values in columns sex and fatal

df_adj["sex"] = df_adj["sex"].str.lower()
df_adj["fatal_(y/n)"] = df_adj["fatal_(y/n)"].str.lower()
df_adj.head()
# Out:
#               year        type    country      area  \
# case_number
# 2016.09.18.c  2016  Unprovoked        USA   Florida
# 2016.09.18.b  2016  Unprovoked        USA   Florida
# 2016.09.18.a  2016  Unprovoked        USA   Florida
# 2016.09.17    2016  Unprovoked  Australia  Victoria
# 2016.09.15    2016  Unprovoked  Australia  Victoria
#
#                                       location activity             name sex  \
# case_number
# 2016.09.18.c  New Smyrna Beach, Volusia County  Surfing             male   m
# 2016.09.18.b  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   m
# 2016.09.18.a  New Smyrna Beach, Volusia County  Surfing             male   m
# 2016.09.17                    Thirteenth Beach  Surfing  Rory Angiolella   m
# 2016.09.15                         Bells Beach  Surfing             male   m
#
#                                              injury fatal_(y/n)  \
# case_number
# 2016.09.18.c                  Minor injury to thigh           n
# 2016.09.18.b                   Lacerations to hands           n
# 2016.09.18.a               Lacerations to lower leg           n
# 2016.09.17             Struck by fin on chest & leg           n
# 2016.09.15    No injury: Knocked off board by shark           n
#
#                    investigator_or_source  clean_date
# case_number
# 2016.09.18.c  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.b  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.18.a  Orlando Sentinel, 9/19/2016  2016.09.18
# 2016.09.17             The Age, 9/18/2016  2016.09.17
# 2016.09.15             The Age, 9/16/2016  2016.09.15

# %%
# Splitting the investigator_or_sourse to get rid of the date in it

check = df_adj["investigator_or_source"].str.split(",", n = 1, expand = True)
df_adj["investigator_source"] = check[0]
df_adj["to_be_dropped"] = check[1]
df_adj = df_adj.drop(["investigator_or_source","to_be_dropped"], axis = 1)
# Out:
#               year        type             country               area  \
# case_number
# 2016.09.18.c  2016  Unprovoked                 USA            Florida
# 2016.09.18.b  2016  Unprovoked                 USA            Florida
# 2016.09.18.a  2016  Unprovoked                 USA            Florida
# 2016.09.17    2016  Unprovoked           Australia           Victoria
# 2016.09.15    2016  Unprovoked           Australia           Victoria
# ...            ...         ...                 ...                ...
# ND.0005          0  Unprovoked           Australia  Western Australia
# ND.0004          0  Unprovoked           Australia  Western Australia
# ND.0003          0  Unprovoked                 USA     North Carolina
# ND.0002          0  Unprovoked              Panama                NaN
# ND.0001          0  Unprovoked  Ceylon (Sri Lanka)   Eastern Province
#
#                                          location      activity  \
# case_number
# 2016.09.18.c     New Smyrna Beach, Volusia County       Surfing
# 2016.09.18.b     New Smyrna Beach, Volusia County       Surfing
# 2016.09.18.a     New Smyrna Beach, Volusia County       Surfing
# 2016.09.17                       Thirteenth Beach       Surfing
# 2016.09.15                            Bells Beach       Surfing
# ...                                           ...           ...
# ND.0005                               Roebuck Bay        Diving
# ND.0004                                       NaN  Pearl diving
# ND.0003                            Ocracoke Inlet      Swimming
# ND.0002                      Panama Bay 8ºN, 79ºW           NaN
# ND.0001       Below the English fort, Trincomalee      Swimming
#
#                                name sex  \
# case_number
# 2016.09.18.c                   male   m
# 2016.09.18.b         Chucky Luciano   m
# 2016.09.18.a                   male   m
# 2016.09.17          Rory Angiolella   m
# 2016.09.15                     male   m
# ...                             ...  ..
# ND.0005                        male   m
# ND.0004                       Ahmun   m
# ND.0003       Coast Guard personnel   m
# ND.0002             Jules Patterson   m
# ND.0001                        male   m
#
#                                                          injury fatal_(y/n)  \
# case_number
# 2016.09.18.c                              Minor injury to thigh           n
# 2016.09.18.b                               Lacerations to hands           n
# 2016.09.18.a                           Lacerations to lower leg           n
# 2016.09.17                         Struck by fin on chest & leg           n
# 2016.09.15                No injury: Knocked off board by shark           n
# ...                                                         ...         ...
# ND.0005                                                   FATAL           y
# ND.0004                                                   FATAL           y
# ND.0003                                                   FATAL           y
# ND.0002                                                   FATAL           y
# ND.0001       FATAL. "Shark bit him in half, carrying away t...           y
#
#               clean_date      investigator_source
# case_number
# 2016.09.18.c  2016.09.18         Orlando Sentinel
# 2016.09.18.b  2016.09.18         Orlando Sentinel
# 2016.09.18.a  2016.09.18         Orlando Sentinel
# 2016.09.17    2016.09.17                  The Age
# 2016.09.15    2016.09.15                  The Age
# ...                  ...                      ...
# ND.0005          ND.0005  H. Taunton; N. Bartlett
# ND.0004          ND.0004  H. Taunton; N. Bartlett
# ND.0003          ND.0003              F. Schwartz
# ND.0002          ND.0002                  The Sun
# ND.0001          ND.0001               S.W. Baker
#
# [5992 rows x 12 columns]

# %%
# Getting rid out of the 0-year data

df_new = df_adj[df_adj["year"] != 0]
df_new
# Out:
#               year        type    country                         area  \
# case_number
# 2016.09.18.c  2016  Unprovoked        USA                      Florida
# 2016.09.18.b  2016  Unprovoked        USA                      Florida
# 2016.09.18.a  2016  Unprovoked        USA                      Florida
# 2016.09.17    2016  Unprovoked  Australia                     Victoria
# 2016.09.15    2016  Unprovoked  Australia                     Victoria
# ...            ...         ...        ...                          ...
# 1554.00.00    1554  Unprovoked     France            Nice & Marseilles
# 1543.00.00    1543  Unprovoked  Venezuela  Magarita or Cubagua Islands
# 0500.00.00     500  Unprovoked     Mexico                          NaN
# 0077.00.00      77  Unprovoked    Unknown                   Ionian Sea
# 0005.00.00       5  Unprovoked  Australia              New South Wales
#
#                                       location       activity  \
# case_number
# 2016.09.18.c  New Smyrna Beach, Volusia County        Surfing
# 2016.09.18.b  New Smyrna Beach, Volusia County        Surfing
# 2016.09.18.a  New Smyrna Beach, Volusia County        Surfing
# 2016.09.17                    Thirteenth Beach        Surfing
# 2016.09.15                         Bells Beach        Surfing
# ...                                        ...            ...
# 1554.00.00                                 NaN            NaN
# 1543.00.00                                 NaN   Pearl diving
# 0500.00.00                                 NaN            NaN
# 0077.00.00                                 NaN  Sponge diving
# 0005.00.00                               Bondi            NaN
#
#                                name  sex  \
# case_number
# 2016.09.18.c                   male    m
# 2016.09.18.b         Chucky Luciano    m
# 2016.09.18.a                   male    m
# 2016.09.17          Rory Angiolella    m
# 2016.09.15                     male    m
# ...                             ...  ...
# 1554.00.00    males (wearing armor)    m
# 1543.00.00             Indian slave    m
# 0500.00.00                     male  NaN
# 0077.00.00                    males    m
# 0005.00.00                     male    m
#
#                                                          injury fatal_(y/n)  \
# case_number
# 2016.09.18.c                              Minor injury to thigh           n
# 2016.09.18.b                               Lacerations to hands           n
# 2016.09.18.a                           Lacerations to lower leg           n
# 2016.09.17                         Struck by fin on chest & leg           n
# 2016.09.15                No injury: Knocked off board by shark           n
# ...                                                         ...         ...
# 1554.00.00                                                  NaN     unknown
# 1543.00.00                                                FATAL           y
# 0500.00.00                                         Foot severed           n
# 0077.00.00                                                FATAL           y
# 0005.00.00    Aboriginal rock carving depicts man being atta...           n
#
#               clean_date                                investigator_source
# case_number
# 2016.09.18.c  2016.09.18                                   Orlando Sentinel
# 2016.09.18.b  2016.09.18                                   Orlando Sentinel
# 2016.09.18.a  2016.09.18                                   Orlando Sentinel
# 2016.09.17    2016.09.17                                            The Age
# 2016.09.15    2016.09.15                                            The Age
# ...                  ...                                                ...
# 1554.00.00    1554.00.00                                       G. Rondelet
# 1543.00.00    1543.00.00                                          J. Castro
# 0500.00.00    0500.00.00                                          J. Castro
# 0077.00.00    0077.00.00  Perils mentioned by Pliny the Elder (23 A.D. t...
# 0005.00.00    0005.00.00                                    Waverly Library
#
# [5868 rows x 12 columns]

# %%
# We don't want to leave any null values left, doesn't matter if they have influence or not

df_new.isnull().sum()
# Out:
# year                     0
# type                     0
# country                  0
# area                   377
# location               462
# activity               508
# name                   193
# sex                    557
# injury                  26
# fatal_(y/n)             19
# clean_date               0
# investigator_source     15
# dtype: int64

# %%
# Removing the null values and putting "unknown" instead

df_new["area"] = df_new["area"].fillna("unknown")
df_new["location"] = df_new["location"].fillna("unknown")
df_new["activity"] = df_new["activity"].fillna("unknown")
df_new["name"] = df_new["name"].fillna("unknown")
df_new["sex"] = df_new["sex"].fillna("unknown")
df_new["injury"] = df_new["injury"].fillna("unknown")
df_new["fatal_(y/n)"] = df_new["fatal_(y/n)"].fillna("unknown")
df_new["investigator_source"] = df_new["investigator_source"].fillna("unknown")
# Out:
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/ilya.ivolgin/miniconda3/envs/day1/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# All the null values are removed

df_new.isnull().sum()
# Out:
# year                   0
# type                   0
# country                0
# area                   0
# location               0
# activity               0
# name                   0
# sex                    0
# injury                 0
# fatal_(y/n)            0
# clean_date             0
# investigator_source    0
# dtype: int64

# %% [markdown]
# ## Data types

# %%
# Getting info about the data types in our dataframe

df_new.dtypes
# Out:
# year                    int64
# type                   object
# country                object
# area                   object
# location               object
# activity               object
# name                   object
# sex                    object
# injury                 object
# fatal_(y/n)            object
# clean_date             object
# investigator_source    object
# dtype: object

# %%
# Changing the data type of year

df_new["year"].astype("object")
# Out:
# case_number
# 2016.09.18.c    2016
# 2016.09.18.b    2016
# 2016.09.18.a    2016
# 2016.09.17      2016
# 2016.09.15      2016
#                 ...
# 1554.00.00      1554
# 1543.00.00      1543
# 0500.00.00       500
# 0077.00.00        77
# 0005.00.00         5
# Name: year, Length: 5868, dtype: object

# %% [markdown]
# ## Changing the order of the columns for dataframe

# %%
df_final = df_new[["clean_date","year","type","country","area","location","activity","name","sex","injury","fatal_(y/n)","investigator_source"]]

# %%
# Final check for null values

df_final.isnull().sum()
# Out:
# clean_date             0
# year                   0
# type                   0
# country                0
# area                   0
# location               0
# activity               0
# name                   0
# sex                    0
# injury                 0
# fatal_(y/n)            0
# investigator_source    0
# dtype: int64

# %%
# Result

df_final.head()
# Out:
#               clean_date  year        type    country      area  \
# case_number
# 2016.09.18.c  2016.09.18  2016  Unprovoked        USA   Florida
# 2016.09.18.b  2016.09.18  2016  Unprovoked        USA   Florida
# 2016.09.18.a  2016.09.18  2016  Unprovoked        USA   Florida
# 2016.09.17    2016.09.17  2016  Unprovoked  Australia  Victoria
# 2016.09.15    2016.09.15  2016  Unprovoked  Australia  Victoria
#
#                                       location activity             name sex  \
# case_number
# 2016.09.18.c  New Smyrna Beach, Volusia County  Surfing             male   m
# 2016.09.18.b  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   m
# 2016.09.18.a  New Smyrna Beach, Volusia County  Surfing             male   m
# 2016.09.17                    Thirteenth Beach  Surfing  Rory Angiolella   m
# 2016.09.15                         Bells Beach  Surfing             male   m
#
#                                              injury fatal_(y/n)  \
# case_number
# 2016.09.18.c                  Minor injury to thigh           n
# 2016.09.18.b                   Lacerations to hands           n
# 2016.09.18.a               Lacerations to lower leg           n
# 2016.09.17             Struck by fin on chest & leg           n
# 2016.09.15    No injury: Knocked off board by shark           n
#
#              investigator_source
# case_number
# 2016.09.18.c    Orlando Sentinel
# 2016.09.18.b    Orlando Sentinel
# 2016.09.18.a    Orlando Sentinel
# 2016.09.17               The Age
# 2016.09.15               The Age

# %%
# Exporting

df_final.to_csv(r'..\data-wrangling.csv')

# %%
import os

# %%
os.path.abspath('.')
# Out:
# '/Users/ilya.ivolgin/data-ber-10-19/module-1_projects/pandas-project/your-code'
